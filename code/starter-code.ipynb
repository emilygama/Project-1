# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Thank you for being here today. My name is Emily Gama. I work for a non-profit called Safe Education. We focus on ensuring high school students in the United States enjoy accessible, safe, and fulfilling education that gives them the foundation to feel successful in whatever life path they choose. We believe that education is extremely important for young people, but also understand that college may not be for everyone. The expectation of attending college and No Child Left Behind policies have ensured that standardized 'college-readiness' tests like the SAT and ACT are very popular and often required to graduate high school. Twenty-six states in the US still require students to take one test or the other in order to graduate (<a href="https://prepmaven.com/blog/test-prep/states-require-sat-act/" target="_blank">Source</a>).
#
# We are here today because I would like us to apply for grant funding to deepen our research on this. This project will look at participation rates and score averages for the SAT and ACT from 2017 and 2019 to explore the relationship between these two aspects. After I analyzed outside research and the initial data, I found that these graduation requirements may be hurting student performance. And, students on average perform better when there is no requirement in place. Those that do not want to take the exams do not have to. Because we don't have enough data yet to delve into this topic further, I am hoping to show you today that this is an important topic to study. I hope that we can pursue this grant funding as our next organization-wide project.
#
# Problem Statement:
# The problem I approached in my project is that standardized testing has been shown to be ineffective and cause increased academic stress. While 76% of colleges are now making the SAT and ACT optional, in 26 states, they are still required to graduate meaning the pressure is still on. I will examine the trends in SAT and ACT scores and participation rates from 2017 to 2019, including outside research on mental health in high school, in hopes to make recommendations on what our next grant application will entail.
#
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).
#
# ---

# %% [markdown]
# ### This section contains both background information and outside research.
#
# While the initial substantial wave of test-optional universities was in response to the COVID-19 pandemic, the list continues to grow of schools that are opting for permanent policies (<a href="https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html" target="_blank">Source</a>, <a href="https://www.fairtest.org/record-1775-schools-are-testoptional-fall-2022" target="_blank">Source</a>). The push behind this is the belief that the tests neither accurately assess college-readiness, nor do they provide any diversity or equality among college applicants (<a href="https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html" target="_blank">Source</a>). There are myriad issues with the tests and their persistence. There is a financial disparity with the tests, favoring those that can afford prep courses. Further, research has shown that white students consistently outperform their minority peers, and it has been suggested these tests and similar teachings styles promote the school-to-prison pipeline (<a href="https://www.researchgate.net/publication/280232788_Race_Poverty_and_SAT_Scores_Modeling_the_Influences_of_Family_Income_on_Black_and_White_High_School_Students'_SAT_Performance" target="_blank">Source</a>, <a href="https://www.fairtest.org/how-testing-feeds-schooltoprison-pipeline" target="_blank">Source</a>). Not to mention, these tests leave a window for wealthy families to manipulate the system as evidenced by the now-infamous testing scandal that involved a few celebrity names (<a href="https://en.wikipedia.org/wiki/2019_college_admissions_bribery_scandal#:~:text=In%202019%2C%20a%20scandal%20arose,code%20named%20Operation%20Varsity%20Blues" target="_blank">Source</a>).
#
# While the lack of requirement to be admitted to college is a welcome and growing movement, there is less focus on the graduation requirement many states hold for their high school seniors. Twenty-six states maintain graduation requirements that mandate students take one of the tests (and cannot qualify with the other), choose between either, or as an alternative to state-created standardized tests (<a href="https://prepmaven.com/blog/test-prep/states-require-sat-act/" target="_blank">Source</a>). I argue that focus on removing the graduation requirement for high school seniors is important as well. With the introduction of the No Child Left Behind policies, standardized testing massively increased in schools, with districts searching for a fair way to manage and test student success (<a href="https://fairtest.org/how-standardized-testing-damages-education-pdf" target="_blank">Source</a>). However, standardized testing furthered by the No Child Left Behind policies and, specifically, the SAT/ACT requirements have consistently been a hindrance to student success than the opposite. Instead of pushing for a measure of learning and college-readiness, these tests and their requirements have created an environment in which students may feel immense pressure, stress, and feelings of worthlessness if they do not measure up to where they are supposed to be, often with little individualized help from administration (<a href="https://fairtest.org/how-standardized-testing-damages-education-pdf" target="_blank">Source</a>).
#
# While this argument applies to all standardized testing within the public education system, I want to focus specifically on the SAT and ACT for this analysis. One 30-year study that examined the same group of students from their middle school years into their thirties found that test anxiety and academic self-esteem concerns were widely pronounced and significant, mostly in their middle school years. They found that these concerns were brought on by many factors, largely including standardized testing and consequences of underperforming on a test (<a href="https://www.sciencedirect.com/science/article/abs/pii/S0165032717303683" target="_blank">Source</a>). Cassady and Johnson studied 168 high schoolers and found that 'high levels of cognitive test anxiety were associated with significantly lower Scholastic Aptitude Test scores' (<a href="https://www.sciencedirect.com/science/article/abs/pii/S0361476X0191094X" target="_blank">Source</a>). This project will aim to evaluate student performance in comparison to participation rates on the SAT and ACT test. Because I was unable to find open-source student mental health data to contribute to this project, I am proposing we apply for grant funding to do a large-scale study on numerous high school students from their preparation to graduate and into college to evaluate the impact academia makes upon mental health.

# %% [markdown]
# ### Choose your Data
#
# I have chosen to work with the ACT and SAT result data from years 2017 to 2019. While I will not add any extra data, this is because I struggled to find outside data that fit within my problem statement that was recent, from the US, and free. Some data exists for the relationship between mental health and standardized testing, but it was not accessible to me. Instead I found visualizations that others had done with the data I could not get myself. I credited those who are responsible for that content.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
temp_nums = [2,4,6,8,10,12,14,16]
def manual_mean(nums):
    return sum(nums)/len(nums)
manual_mean(temp_nums)
# Out:
# 9.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def manual_stdev(nums):
    return (manual_mean([(num-manual_mean(nums))**2 for num in nums]))**0.5
manual_stdev(temp_nums)
# Out:
# 4.58257569495584

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def clean_percents(string_percents):
    for x in string_percents:
        return float(string_percents.replace('%', ''))/100
clean_percents('47%')
# Out:
# 0.47

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:

# %%
act_2017 = pd.read_csv('./data/act_2017.csv') 
act_2018 = pd.read_csv('./data/act_2018.csv')
act_2019 = pd.read_csv('./data/act_2019.csv')
sat_2017 = pd.read_csv('./data/sat_2017.csv')
sat_2018 = pd.read_csv('./data/sat_2018.csv')
sat_2019 = pd.read_csv('./data/sat_2019.csv')

# %% [markdown]
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.

# %%
# Viewing the first few rows and then the info and dtypes for each dataset
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
# To check for nulls
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# * For the ACT, the composite score is an average of the four subjects, with the lowest score at 1 and highest possible at 36. <a href="https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html" target="_blank">Source</a>
# * For the SAT, there are two tests, each with a possible score of 200-800. The total score is the sum of both, making the total possible score 400-1600. <a href="https://satsuite.collegeboard.org/sat/scores/understanding-scores/how-scores-are-calculated" target="_blank">Source</a>

# %% [markdown]
# In attempting to test the accuracy of the composite scores in the 2017 ACT dataset, I realized the composite scores were objects instead of floats. First, I found and fixed that issue, then I was able to set up a test mean column to see if the composite scores were accurate. Due to not having all test score data, only averages, I expect the scores will not exactly match.

# %%
act_2017['Composite'] = act_2017['Composite'].str.replace('x', '').astype(float)  #Changed the dtype to float instead of object. I had to remove the 'x' off one of the values in order to do that.

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB

# %%
act_2017['Test'] = manual_mean([act_2017['Reading'], act_2017['English'], act_2017['Science'], act_2017['Math']]).round(1)

# %%
act_2017.head(3)
# Out:
#      State  Participation  Composite
# 1  Alabama           1.00       19.2
# 2   Alaska           0.65       19.8
# 3  Arizona           0.62       19.7

# %% [markdown]
# For the most part, the scores match up, except in Maryland (shown below) where an abnormally low average on the ['Science'] exam skewed the data. Because my manual mean was significantly lower than the provided composite score, I can assume the low score is a typo. To fix this, I will manually calculate backwards using the composite score to find what the average should be.

# %%
act_2017.iloc[21, 2:]
# Out:
# English      23.3
# Math         23.1
# Reading      24.2
# Science       2.3
# Composite    23.6
# Test         18.2
# Name: 21, dtype: object

# %%
23.6*4-(23.3+23.1+24.2)
# Back calcualting
# Out:
# 23.799999999999997

# %% [markdown]
# Assuming the composite scores are correct, it appears the score should've been 23.8 instead of 2.3.

# %%
act_2017.iloc[21, 5] = 23.8   #fixing the score

# %%
act_2017.iloc[21, 2:]
# Out:
# English      23.3
# Math         23.1
# Reading      24.2
# Science      23.8
# Composite    23.6
# Test         18.2
# Name: 21, dtype: object

# %%
act_2017['Test'] = manual_mean([act_2017['Reading'], act_2017['English'], act_2017['Science'], act_2017['Math']]).round(1)    # Now I can check the scores to ensure accuracy

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act_2017['Composite'].sort_values()
# Out:
# 29    17.8
# 25    18.6
# 41    18.7
# 12    19.0
# 34    19.1
# 1     19.2
# 4     19.4
# 37    19.4
# 19    19.5
# 3     19.7
# 32    19.7
# 2     19.8
# 43    19.8
# 10    19.8
# 18    20.0
# 51    20.2
# 35    20.3
# 27    20.3
# 45    20.3
# 49    20.4
# 26    20.4
# 50    20.5
# 44    20.7
# 6     20.8
# 0     21.0
# 14    21.4
# 28    21.4
# 11    21.4
# 24    21.5
# 17    21.7
# 42    21.8
# 38    21.8
# 48    21.9
# 16    21.9
# 36    22.0
# 13    22.3
# 15    22.6
# 5     22.8
# 46    23.6
# 21    23.6
# 39    23.7
# 47    23.8
# 31    23.9
# 40    24.0
# 8     24.1
# 23    24.1
# 9     24.2
# 33    24.2
# 20    24.3
# 7     25.2
# 22    25.4
# 30    25.5
# Name: Composite, dtype: float64

# %%
act_2017['Participation'].sort_values()
# Out:
# 0      60%
# 45    100%
# 43    100%
# 41    100%
# 37    100%
# 34    100%
# 29    100%
# 27    100%
# 26    100%
# 50    100%
# 24    100%
# 19    100%
# 18    100%
# 25    100%
# 51    100%
# 4     100%
# 6     100%
# 1     100%
# 30     18%
# 8      18%
# 40     21%
# 39     23%
# 21     28%
# 48     29%
# 46     29%
# 23     29%
# 22     29%
# 47     29%
# 7      31%
# 33     31%
# 5      31%
# 9      32%
# 31     34%
# 15     35%
# 13     38%
# 38     40%
# 44     45%
# 11     55%
# 3      62%
# 2      65%
# 32     66%
# 16     67%
# 49     69%
# 10     73%
# 17     73%
# 36     75%
# 20      8%
# 42     80%
# 28     84%
# 12     90%
# 14     93%
# 35     98%
# Name: Participation, dtype: object

# %% [markdown]
# We can see above that the low score has been fixed. As well, there are no issues in the participation rate or other composite issues. Now to check the other dataframes.

# %%
act_2018['Composite'].sort_values()
# Out:
# 29    17.7
# 41    18.3
# 25    18.6
# 11    18.9
# 34    19.1
# 0     19.1
# 2     19.2
# 18    19.2
# 37    19.3
# 32    19.4
# 3     19.4
# 43    19.6
# 9     19.9
# 51    20.0
# 27    20.0
# 26    20.0
# 28    20.1
# 17    20.2
# 49    20.3
# 36    20.3
# 35    20.3
# 45    20.4
# 50    20.5
# 44    20.7
# 1     20.8
# 38    21.3
# 24    21.3
# 10    21.4
# 16    21.6
# 15    21.8
# 42    21.9
# 48    22.2
# 12    22.3
# 14    22.5
# 21    22.5
# 4     22.7
# 39    23.5
# 8     23.6
# 31    23.7
# 7     23.8
# 47    23.9
# 5     23.9
# 13    23.9
# 20    24.0
# 19    24.0
# 46    24.1
# 23    24.2
# 40    24.2
# 33    24.5
# 30    25.1
# 22    25.5
# 6     25.6
# Name: Composite, dtype: float64

# %%
act_2018['Participation'].sort_values()
# Out:
# 0     100%
# 45    100%
# 43    100%
# 41    100%
# 37    100%
# 36    100%
# 34    100%
# 29    100%
# 28    100%
# 27    100%
# 26    100%
# 50    100%
# 18    100%
# 17    100%
# 25    100%
# 51    100%
# 3     100%
# 40     15%
# 30     16%
# 7      17%
# 39     20%
# 23     22%
# 48     24%
# 47     24%
# 46     24%
# 22     25%
# 6      26%
# 4      27%
# 33     27%
# 5      30%
# 31     31%
# 21     31%
# 14     32%
# 8      32%
# 1      33%
# 12     36%
# 38     42%
# 13     43%
# 44     45%
# 10     53%
# 49     65%
# 9      66%
# 2      66%
# 32     67%
# 15     68%
# 19      7%
# 20      7%
# 16     71%
# 42     77%
# 11     89%
# 35     98%
# 24     99%
# Name: Participation, dtype: object

# %%
act_2019['Composite'].sort_values()
# Out:
# 28    17.9
# 24    18.4
# 18    18.8
# 40    18.8
# 36    18.9
# 0     18.9
# 33    19.0
# 2     19.0
# 11    19.0
# 3     19.3
# 31    19.3
# 42    19.4
# 50    19.8
# 17    19.8
# 26    19.8
# 34    19.9
# 35    20.0
# 27    20.0
# 9     20.1
# 1     20.1
# 44    20.3
# 49    20.3
# 43    20.5
# 51    20.7
# 25    20.8
# 48    20.8
# 37    21.1
# 16    21.2
# 10    21.4
# 23    21.4
# 15    21.6
# 41    21.6
# 47    22.1
# 20    22.3
# 14    22.5
# 12    22.5
# 4     22.6
# 8     23.5
# 38    23.6
# 5     23.8
# 46    24.0
# 7     24.1
# 45    24.1
# 30    24.2
# 13    24.3
# 19    24.3
# 22    24.4
# 32    24.5
# 39    24.7
# 29    25.0
# 21    25.5
# 6     25.5
# Name: Composite, dtype: float64

# %%
act_2019['Participation'].sort_values()
# Out:
# 0     100%
# 36    100%
# 35    100%
# 33    100%
# 42    100%
# 28    100%
# 27    100%
# 26    100%
# 50    100%
# 24    100%
# 18    100%
# 17    100%
# 44    100%
# 3     100%
# 49    100%
# 39     12%
# 7      13%
# 29     14%
# 38     17%
# 22     19%
# 45     20%
# 21     21%
# 46     21%
# 32     22%
# 6      22%
# 4      23%
# 47     24%
# 30     25%
# 5      27%
# 20     28%
# 14     29%
# 12     31%
# 8      32%
# 13     35%
# 1      38%
# 43     39%
# 37     42%
# 10     49%
# 48     49%
# 51     52%
# 9      54%
# 19      6%
# 31     63%
# 15     66%
# 16     72%
# 2      73%
# 41     75%
# 40     78%
# 11     80%
# 25     82%
# 23     95%
# 34     96%
# Name: Participation, dtype: object

# %% [markdown]
# Both the act_2018 and act_2019 dataframes consist only of the composite score, instead of the breakdown. However, I still checked to see if either had any glaring issues, such as negative percents or composites in the 80s. Neither have any. On to SAT dataframes. Since all of these are formatted the same, I will attempt to create a function that will check their scores in one fell swoop. First I need to ensure there are no value issues.

# %%
sat_2017  #simply viewing the data because it is such a small data set, it looks clean
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
sat_2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %% [markdown]
# The sat_2019 dataset appears to have some dashes inplace of participation rates. I will remove these values since Puerto Rico and Virgin Islands are not included in the other datasets.

# %%
sat_2019 = sat_2019.drop(index=[39, 47])
sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %% [markdown]
# All fixed! This finding made me consider if there were erroneous rows in the ACT datasets. I will check those again.

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act_2018
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
act_2019
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %% [markdown]
# Well, I'm glad I did that! I noticed there is a duplicate value for Maine in the ACT 2018 dataset, and there is an entry for 'National' in the ACT 2017 and ACT 2019 datasets. I will remove these as well. If I were working with larger datasets, I could merge them and remove entries that don't match, or I could do df.duplicates() to find errors.

# %%
act_2017 = act_2017.drop(index=0)

# %%
act_2018 = act_2018.drop(index=19)

# %%
act_2019 = act_2019.drop(index=51)

# %%
act_2017.shape
# Out:
# (51, 8)

# %%
act_2018.shape
# Out:
# (51, 3)

# %%
act_2019.shape
# Out:
# (51, 3)

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
sat_2018.shape
# Out:
# (51, 5)

# %%
sat_2019.shape
# Out:
# (51, 5)

# %% [markdown]
# Much better! Finally, I can check total scores for the SAT and create that function I mentioned a while back. First, I will rename the EBRW columns to all match.

# %%
# def check_sat_scores(df):
#     df['test'] = sum([df.iloc[2], df.iloc[3]])
#     if df['test'].equals(df.iloc[4]): 
#         return True
# Tried the above but cannot sum with iloc. Therefore, I have to change the names of the columns in sat_2017 and sat_2018 to match sat_2019 so I can use column names in the function.

# %%
sat_2017.rename(columns={'Evidence-Based Reading and Writing':'EBRW'}, inplace=True)
sat_2017
# Out:
#                    State Participation  EBRW  Math  Total
# 0                Alabama            5%   593   572   1165
# 1                 Alaska           38%   547   533   1080
# 2                Arizona           30%   563   553   1116
# 3               Arkansas            3%   614   594   1208
# 4             California           53%   531   524   1055
# 5               Colorado           11%   606   595   1201
# 6            Connecticut          100%   530   512   1041
# 7               Delaware          100%   503   492    996
# 8   District of Columbia          100%   482   468    950
# 9                Florida           83%   520   497   1017
# 10               Georgia           61%   535   515   1050
# 11                Hawaii           55%   544   541   1085
# 12                 Idaho           93%   513   493   1005
# 13              Illinois            9%   559   556   1115
# 14               Indiana           63%   542   532   1074
# ...

# %%
sat_2018.rename(columns={'Evidence-Based Reading and Writing':'EBRW'}, inplace=True)
sat_2018
# Out:
#                    State Participation  EBRW  Math  Total
# 0                Alabama            6%   595   571   1166
# 1                 Alaska           43%   562   544   1106
# 2                Arizona           29%   577   572   1149
# 3               Arkansas            5%   592   576   1169
# 4             California           60%   540   536   1076
# 5               Colorado          100%   519   506   1025
# 6            Connecticut          100%   535   519   1053
# 7               Delaware          100%   505   492    998
# 8   District of Columbia           92%   497   480    977
# 9                Florida           56%   550   549   1099
# 10               Georgia           70%   542   522   1064
# 11                Hawaii           56%   480   530   1010
# 12                 Idaho          100%   508   493   1001
# 13              Illinois           99%   513   506   1019
# 14               Indiana           63%   542   532   1074
# ...

# %%
def check_sat_scores(df):
    df['test'] = sum([df['EBRW'], df['Math']])
    if df['test'].equals(df['Total']): 
        return True
    else:
        return print('Check manually')

# %%
check_sat_scores(sat_2017)
# Out:
# Check manually

# %%
sat_2017  #Looks like we have an issue with Maryland again. All others look close enough.
# Out:
#                    State Participation  EBRW  Math  Total  test
# 0                Alabama            5%   593   572   1165  1165
# 1                 Alaska           38%   547   533   1080  1080
# 2                Arizona           30%   563   553   1116  1116
# 3               Arkansas            3%   614   594   1208  1208
# 4             California           53%   531   524   1055  1055
# 5               Colorado           11%   606   595   1201  1201
# 6            Connecticut          100%   530   512   1041  1042
# 7               Delaware          100%   503   492    996   995
# 8   District of Columbia          100%   482   468    950   950
# 9                Florida           83%   520   497   1017  1017
# 10               Georgia           61%   535   515   1050  1050
# 11                Hawaii           55%   544   541   1085  1085
# 12                 Idaho           93%   513   493   1005  1006
# 13              Illinois            9%   559   556   1115  1115
# ...

# %%
check_sat_scores(sat_2018)
# Out:
# Check manually

# %%
sat_2018   # All set here
# Out:
#                    State Participation  EBRW  Math  Total  test
# 0                Alabama            6%   595   571   1166  1166
# 1                 Alaska           43%   562   544   1106  1106
# 2                Arizona           29%   577   572   1149  1149
# 3               Arkansas            5%   592   576   1169  1168
# 4             California           60%   540   536   1076  1076
# 5               Colorado          100%   519   506   1025  1025
# 6            Connecticut          100%   535   519   1053  1054
# 7               Delaware          100%   505   492    998   997
# 8   District of Columbia           92%   497   480    977   977
# 9                Florida           56%   550   549   1099  1099
# 10               Georgia           70%   542   522   1064  1064
# 11                Hawaii           56%   480   530   1010  1010
# 12                 Idaho          100%   508   493   1001  1001
# 13              Illinois           99%   513   506   1019  1019
# ...

# %%
check_sat_scores(sat_2019)
# Out:
# Check manually

# %%
sat_2019  # All set
# Out:
#                    State Participation Rate  EBRW  Math  Total  test
# 0                Alabama                 7%   583   560   1143  1143
# 1                 Alaska                41%   556   541   1097  1097
# 2                Arizona                31%   569   565   1134  1134
# 3               Arkansas                 6%   582   559   1141  1141
# 4             California                63%   534   531   1065  1065
# 5               Colorado               100%   518   506   1024  1024
# 6            Connecticut               100%   529   516   1046  1045
# 7               Delaware               100%   499   486    985   985
# 8   District of Columbia                94%   495   480    975   975
# 9                Florida               100%   516   483    999   999
# 10               Georgia                71%   538   519   1058  1057
# 11                Hawaii                54%   550   550   1100  1100
# 12                 Idaho               100%   505   488    993   993
# ...

# %% [markdown]
# To fix the Maryland issue, I will do the same as with the ACT scores. I will backwards calculate what the score should be, assuming the total is correct.

# %%
sat_2017.iloc[20,2:]
# Out:
# EBRW      536
# Math       52
# Total    1060
# test      588
# Name: 20, dtype: object

# %%
1060-536
# Out:
# 524

# %% [markdown]
# Looks like the score should be 524 not 52, meaning typo.

# %%
sat_2017.iloc[20,3] = 524
sat_2017.iloc[20,2:]
# Out:
# EBRW      536
# Math      524
# Total    1060
# test      588
# Name: 20, dtype: object

# %%
check_sat_scores(sat_2017)  #Running this again to get the right test column
# Out:
# Check manually

# %%
sat_2017  #Great! On to fixing the percent issue!
# Out:
#                    State Participation  EBRW  Math  Total  test
# 0                Alabama            5%   593   572   1165  1165
# 1                 Alaska           38%   547   533   1080  1080
# 2                Arizona           30%   563   553   1116  1116
# 3               Arkansas            3%   614   594   1208  1208
# 4             California           53%   531   524   1055  1055
# 5               Colorado           11%   606   595   1201  1201
# 6            Connecticut          100%   530   512   1041  1042
# 7               Delaware          100%   503   492    996   995
# 8   District of Columbia          100%   482   468    950   950
# 9                Florida           83%   520   497   1017  1017
# 10               Georgia           61%   535   515   1050  1050
# 11                Hawaii           55%   544   541   1085  1085
# 12                 Idaho           93%   513   493   1005  1006
# 13              Illinois            9%   559   556   1115  1115
# ...

# %% [markdown]
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.

# %%
act_2017['Participation'] = act_2017['Participation'].map(clean_percents)  #using .map() to ensure the function walks through each value
act_2017
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
# 11               Georgia           0.55     21.0  20.9     22.0     21.3
# 12                Hawaii           0.90     17.8  19.2     19.2     19.3
# ...

# %%
act_2018['Participation'] = act_2018['Participation'].map(clean_percents)
act_2018
# Out:
#                    State  Participation  Composite
# 0                Alabama           1.00       19.1
# 1                 Alaska           0.33       20.8
# 2                Arizona           0.66       19.2
# 3               Arkansas           1.00       19.4
# 4             California           0.27       22.7
# 5               Colorado           0.30       23.9
# 6            Connecticut           0.26       25.6
# 7               Delaware           0.17       23.8
# 8   District of columbia           0.32       23.6
# 9                Florida           0.66       19.9
# 10               Georgia           0.53       21.4
# 11                Hawaii           0.89       18.9
# 12                 Idaho           0.36       22.3
# 13              Illinois           0.43       23.9
# 14               Indiana           0.32       22.5
# 15                  Iowa           0.68       21.8
# 16                Kansas           0.71       21.6
# ...

# %%
act_2019['Participation'] = act_2019['Participation'].map(clean_percents)
act_2019
# Out:
#                    State  Participation  Composite
# 0                Alabama           1.00       18.9
# 1                 Alaska           0.38       20.1
# 2                Arizona           0.73       19.0
# 3               Arkansas           1.00       19.3
# 4             California           0.23       22.6
# 5               Colorado           0.27       23.8
# 6            Connecticut           0.22       25.5
# 7               Delaware           0.13       24.1
# 8   District of Columbia           0.32       23.5
# 9                Florida           0.54       20.1
# 10               Georgia           0.49       21.4
# 11                Hawaii           0.80       19.0
# 12                 Idaho           0.31       22.5
# 13              Illinois           0.35       24.3
# 14               Indiana           0.29       22.5
# 15                  Iowa           0.66       21.6
# 16                Kansas           0.72       21.2
# ...

# %%
sat_2017['Participation'] = sat_2017['Participation'].map(clean_percents)
sat_2017
# Out:
#                    State  Participation  EBRW  Math  Total  test
# 0                Alabama           0.05   593   572   1165  1165
# 1                 Alaska           0.38   547   533   1080  1080
# 2                Arizona           0.30   563   553   1116  1116
# 3               Arkansas           0.03   614   594   1208  1208
# 4             California           0.53   531   524   1055  1055
# 5               Colorado           0.11   606   595   1201  1201
# 6            Connecticut           1.00   530   512   1041  1042
# 7               Delaware           1.00   503   492    996   995
# 8   District of Columbia           1.00   482   468    950   950
# 9                Florida           0.83   520   497   1017  1017
# 10               Georgia           0.61   535   515   1050  1050
# 11                Hawaii           0.55   544   541   1085  1085
# 12                 Idaho           0.93   513   493   1005  1006
# ...

# %%
sat_2018['Participation'] = sat_2018['Participation'].map(clean_percents)
sat_2018
# Out:
#                    State  Participation  EBRW  Math  Total  test
# 0                Alabama           0.06   595   571   1166  1166
# 1                 Alaska           0.43   562   544   1106  1106
# 2                Arizona           0.29   577   572   1149  1149
# 3               Arkansas           0.05   592   576   1169  1168
# 4             California           0.60   540   536   1076  1076
# 5               Colorado           1.00   519   506   1025  1025
# 6            Connecticut           1.00   535   519   1053  1054
# 7               Delaware           1.00   505   492    998   997
# 8   District of Columbia           0.92   497   480    977   977
# 9                Florida           0.56   550   549   1099  1099
# 10               Georgia           0.70   542   522   1064  1064
# 11                Hawaii           0.56   480   530   1010  1010
# 12                 Idaho           1.00   508   493   1001  1001
# ...

# %%
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(clean_percents)
sat_2019
# Out:
#                    State  Participation Rate  EBRW  Math  Total  test
# 0                Alabama                0.07   583   560   1143  1143
# 1                 Alaska                0.41   556   541   1097  1097
# 2                Arizona                0.31   569   565   1134  1134
# 3               Arkansas                0.06   582   559   1141  1141
# 4             California                0.63   534   531   1065  1065
# 5               Colorado                1.00   518   506   1024  1024
# 6            Connecticut                1.00   529   516   1046  1045
# 7               Delaware                1.00   499   486    985   985
# 8   District of Columbia                0.94   495   480    975   975
# 9                Florida                1.00   516   483    999   999
# 10               Georgia                0.71   538   519   1058  1057
# 11                Hawaii                0.54   550   550   1100  1100
# ...

# %% [markdown]
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).

# %%
act_2017.drop(columns=['English', 'Math', 'Reading','Science', 'Test'], inplace=True)  #since I will be using only the composite scores, I will drop the subject columns
act_2017
# Out:
#                    State  Participation  Composite
# 1                Alabama           1.00       19.2
# 2                 Alaska           0.65       19.8
# 3                Arizona           0.62       19.7
# 4               Arkansas           1.00       19.4
# 5             California           0.31       22.8
# 6               Colorado           1.00       20.8
# 7            Connecticut           0.31       25.2
# 8               Delaware           0.18       24.1
# 9   District of Columbia           0.32       24.2
# 10               Florida           0.73       19.8
# 11               Georgia           0.55       21.4
# 12                Hawaii           0.90       19.0
# 13                 Idaho           0.38       22.3
# 14              Illinois           0.93       21.4
# 15               Indiana           0.35       22.6
# 16                  Iowa           0.67       21.9
# 17                Kansas           0.73       21.7
# ...

# %%
sat_2017.drop(columns=['EBRW', 'Math', 'test'], inplace=True)
sat_2017
# Out:
#                    State  Participation  Total
# 0                Alabama           0.05   1165
# 1                 Alaska           0.38   1080
# 2                Arizona           0.30   1116
# 3               Arkansas           0.03   1208
# 4             California           0.53   1055
# 5               Colorado           0.11   1201
# 6            Connecticut           1.00   1041
# 7               Delaware           1.00    996
# 8   District of Columbia           1.00    950
# 9                Florida           0.83   1017
# 10               Georgia           0.61   1050
# 11                Hawaii           0.55   1085
# 12                 Idaho           0.93   1005
# 13              Illinois           0.09   1115
# 14               Indiana           0.63   1074
# 15                  Iowa           0.02   1275
# 16                Kansas           0.04   1260
# 17              Kentucky           0.04   1247
# 18             Louisiana           0.04   1198
# ...

# %%
sat_2018.drop(columns=['EBRW', 'Math', 'test'], inplace=True)
sat_2018
# Out:
#                    State  Participation  Total
# 0                Alabama           0.06   1166
# 1                 Alaska           0.43   1106
# 2                Arizona           0.29   1149
# 3               Arkansas           0.05   1169
# 4             California           0.60   1076
# 5               Colorado           1.00   1025
# 6            Connecticut           1.00   1053
# 7               Delaware           1.00    998
# 8   District of Columbia           0.92    977
# 9                Florida           0.56   1099
# 10               Georgia           0.70   1064
# 11                Hawaii           0.56   1010
# 12                 Idaho           1.00   1001
# 13              Illinois           0.99   1019
# 14               Indiana           0.63   1074
# 15                  Iowa           0.03   1265
# 16                Kansas           0.04   1265
# 17              Kentucky           0.04   1248
# 18             Louisiana           0.04   1210
# ...

# %%
sat_2019.drop(columns=['EBRW', 'Math', 'test'], inplace=True)
sat_2019
# Out:
#                    State  Participation Rate  Total
# 0                Alabama                0.07   1143
# 1                 Alaska                0.41   1097
# 2                Arizona                0.31   1134
# 3               Arkansas                0.06   1141
# 4             California                0.63   1065
# 5               Colorado                1.00   1024
# 6            Connecticut                1.00   1046
# 7               Delaware                1.00    985
# 8   District of Columbia                0.94    975
# 9                Florida                1.00    999
# 10               Georgia                0.71   1058
# 11                Hawaii                0.54   1100
# 12                 Idaho                1.00    993
# 13              Illinois                1.00   1013
# 14               Indiana                0.66   1080
# 15                  Iowa                0.03   1244
# 16                Kansas                0.04   1241
# ...

# %%
act_2017clean = act_2017.rename(columns={   #renaming the columns according to requirements
    'State':'state',
    'Participation':'act_participation_2017',
    'Composite':'act_composite_2017'
    })
act_2017clean
# Out:
#                    state  act_participation_2017  act_composite_2017
# 1                Alabama                    1.00                19.2
# 2                 Alaska                    0.65                19.8
# 3                Arizona                    0.62                19.7
# 4               Arkansas                    1.00                19.4
# 5             California                    0.31                22.8
# 6               Colorado                    1.00                20.8
# 7            Connecticut                    0.31                25.2
# 8               Delaware                    0.18                24.1
# 9   District of Columbia                    0.32                24.2
# 10               Florida                    0.73                19.8
# 11               Georgia                    0.55                21.4
# 12                Hawaii                    0.90                19.0
# 13                 Idaho                    0.38                22.3
# ...

# %%
act_2018clean = act_2018.rename(columns={
    'State':'state',
    'Participation':'act_participation_2018',
    'Composite':'act_composite_2018'
    })
act_2018clean
# Out:
#                    state  act_participation_2018  act_composite_2018
# 0                Alabama                    1.00                19.1
# 1                 Alaska                    0.33                20.8
# 2                Arizona                    0.66                19.2
# 3               Arkansas                    1.00                19.4
# 4             California                    0.27                22.7
# 5               Colorado                    0.30                23.9
# 6            Connecticut                    0.26                25.6
# 7               Delaware                    0.17                23.8
# 8   District of columbia                    0.32                23.6
# 9                Florida                    0.66                19.9
# 10               Georgia                    0.53                21.4
# 11                Hawaii                    0.89                18.9
# 12                 Idaho                    0.36                22.3
# ...

# %%
act_2019clean = act_2019.rename(columns={
    'State':'state',
    'Participation':'act_participation_2019',
    'Composite':'act_composite_2019'
    })
act_2019clean
# Out:
#                    state  act_participation_2019  act_composite_2019
# 0                Alabama                    1.00                18.9
# 1                 Alaska                    0.38                20.1
# 2                Arizona                    0.73                19.0
# 3               Arkansas                    1.00                19.3
# 4             California                    0.23                22.6
# 5               Colorado                    0.27                23.8
# 6            Connecticut                    0.22                25.5
# 7               Delaware                    0.13                24.1
# 8   District of Columbia                    0.32                23.5
# 9                Florida                    0.54                20.1
# 10               Georgia                    0.49                21.4
# 11                Hawaii                    0.80                19.0
# 12                 Idaho                    0.31                22.5
# ...

# %%
sat_2017clean = sat_2017.rename(columns={
    'State':'state',
    'Participation':'sat_participation_2017',
    'Total':'sat_total_2017'
    })
sat_2017clean
# Out:
#                    state  sat_participation_2017  sat_total_2017
# 0                Alabama                    0.05            1165
# 1                 Alaska                    0.38            1080
# 2                Arizona                    0.30            1116
# 3               Arkansas                    0.03            1208
# 4             California                    0.53            1055
# 5               Colorado                    0.11            1201
# 6            Connecticut                    1.00            1041
# 7               Delaware                    1.00             996
# 8   District of Columbia                    1.00             950
# 9                Florida                    0.83            1017
# 10               Georgia                    0.61            1050
# 11                Hawaii                    0.55            1085
# 12                 Idaho                    0.93            1005
# ...

# %%
sat_2018clean = sat_2018.rename(columns={
    'State':'state',
    'Participation':'sat_participation_2018',
    'Total':'sat_total_2018'
    })
sat_2018clean
# Out:
#                    state  sat_participation_2018  sat_total_2018
# 0                Alabama                    0.06            1166
# 1                 Alaska                    0.43            1106
# 2                Arizona                    0.29            1149
# 3               Arkansas                    0.05            1169
# 4             California                    0.60            1076
# 5               Colorado                    1.00            1025
# 6            Connecticut                    1.00            1053
# 7               Delaware                    1.00             998
# 8   District of Columbia                    0.92             977
# 9                Florida                    0.56            1099
# 10               Georgia                    0.70            1064
# 11                Hawaii                    0.56            1010
# 12                 Idaho                    1.00            1001
# ...

# %%
sat_2019clean = sat_2019.rename(columns={
    'State':'state',
    'Participation Rate':'sat_participation_2019',
    'Total':'sat_total_2019'
    })
sat_2019clean
# Out:
#                    state  sat_participation_2019  sat_total_2019
# 0                Alabama                    0.07            1143
# 1                 Alaska                    0.41            1097
# 2                Arizona                    0.31            1134
# 3               Arkansas                    0.06            1141
# 4             California                    0.63            1065
# 5               Colorado                    1.00            1024
# 6            Connecticut                    1.00            1046
# 7               Delaware                    1.00             985
# 8   District of Columbia                    0.94             975
# 9                Florida                    1.00             999
# 10               Georgia                    0.71            1058
# 11                Hawaii                    0.54            1100
# 12                 Idaho                    1.00             993
# ...

# %% [markdown]
# 9. Merge dataframes that can be merged.

# %%
act_merged = pd.merge(left=act_2017clean, right=act_2018clean, on='state')  #I'm merging the datasets into their respective ones for each test. This will help me later for visualizations. 
act_merged
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                    1.00                19.2
# 1           Alaska                    0.65                19.8
# 2          Arizona                    0.62                19.7
# 3         Arkansas                    1.00                19.4
# 4       California                    0.31                22.8
# 5         Colorado                    1.00                20.8
# 6      Connecticut                    0.31                25.2
# 7         Delaware                    0.18                24.1
# 8          Florida                    0.73                19.8
# 9          Georgia                    0.55                21.4
# 10          Hawaii                    0.90                19.0
# 11           Idaho                    0.38                22.3
# 12        Illinois                    0.93                21.4
# 13         Indiana                    0.35                22.6
# ...

# %%
act_merged = pd.merge(left=act_merged, right=act_2019clean, on='state')
act_merged
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                    1.00                19.2
# 1           Alaska                    0.65                19.8
# 2          Arizona                    0.62                19.7
# 3         Arkansas                    1.00                19.4
# 4       California                    0.31                22.8
# 5         Colorado                    1.00                20.8
# 6      Connecticut                    0.31                25.2
# 7         Delaware                    0.18                24.1
# 8          Florida                    0.73                19.8
# 9          Georgia                    0.55                21.4
# 10          Hawaii                    0.90                19.0
# 11           Idaho                    0.38                22.3
# 12        Illinois                    0.93                21.4
# 13         Indiana                    0.35                22.6
# ...

# %%
sat_merged = pd.merge(left=sat_2017clean, right=sat_2018clean, on='state')
sat_merged
# Out:
#                    state  sat_participation_2017  sat_total_2017  \
# 0                Alabama                    0.05            1165
# 1                 Alaska                    0.38            1080
# 2                Arizona                    0.30            1116
# 3               Arkansas                    0.03            1208
# 4             California                    0.53            1055
# 5               Colorado                    0.11            1201
# 6            Connecticut                    1.00            1041
# 7               Delaware                    1.00             996
# 8   District of Columbia                    1.00             950
# 9                Florida                    0.83            1017
# 10               Georgia                    0.61            1050
# 11                Hawaii                    0.55            1085
# 12                 Idaho                    0.93            1005
# ...

# %%
sat_merged = pd.merge(left=sat_merged, right=sat_2019clean, on='state')
sat_merged
# Out:
#                    state  sat_participation_2017  sat_total_2017  \
# 0                Alabama                    0.05            1165
# 1                 Alaska                    0.38            1080
# 2                Arizona                    0.30            1116
# 3               Arkansas                    0.03            1208
# 4             California                    0.53            1055
# 5               Colorado                    0.11            1201
# 6            Connecticut                    1.00            1041
# 7               Delaware                    1.00             996
# 8   District of Columbia                    1.00             950
# 9                Florida                    0.83            1017
# 10               Georgia                    0.61            1050
# 11                Hawaii                    0.55            1085
# 12                 Idaho                    0.93            1005
# ...

# %% [markdown]
# 11. Save your cleaned and merged dataframes as csv files.

# %%
pwd  #Ensuring I'm in the right place
# Out:
# '/Users/ER/Desktop/GA:ADA/Course_Materials/project1/project-1'

# %%
act_2017clean.to_csv('./data/act_2017clean.csv')
# help on the to_csv method from: https://stackoverflow.com/questions/62396245/saving-my-dataset-as-a-csv-file-in-python

# %%
act_2018clean.to_csv('./data/act_2018clean.csv')
act_2019clean.to_csv('./data/act_2019clean.csv')
sat_2017clean.to_csv('./data/sat_2017clean.csv')
sat_2018clean.to_csv('./data/sat_2018clean.csv')
sat_2019clean.to_csv('./data/sat_2019clean.csv')

# %%
act_merged.to_csv('./data/act_merged.csv')
sat_merged.to_csv('./data/sat_merged.csv')

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|*object*|all datasets|The state name in alphabetical order|
# |act_participation_2017|*float*|act_2017clean, act_merged| The participation rate by state of graduating high school students who took the ACT during the 2016/2017 year (in decimal form, ex: .40 means 40%)|
# |act_composite_2017|*float*|act_2017clean, act_merged| The composite score (average of the four subjects) for the graduating high school students who took the test during the 2016/2017 year|
# |act_participation_2018|*float*|act_2018clean, act_merged| The participation rate by state of graduating high school students who took the ACT during the 2017/2018 year (in decimal form, ex: .40 means 40%)|
# |act_composite_2018|*float*|act_2018clean, act_merged| The composite score (average of the four subjects) for the graduating high school students who took the test during the 2017/2018 year|
# |act_participation_2019|*float*|act_2019clean, act_merged| The participation rate by state of graduating high school students who took the ACT during the 2018/2019 year (in decimal form, ex: .40 means 40%)|
# |act_composite_2019|*float*|act_2019clean, act_merged| The composite score (average of the four subjects) for the graduating high school students who took the test during the 2018/2019 year|
# |sat_participation_2017|*float*|sat_2017clean, sat_merged| The participation rate by state of graduating high school students who took the SAT during the 2016/2017 year (in decimal form, ex: .40 means 40%)|
# |sat_total_2017|*integer*|sat_2017clean, sat_merged| The total score (sum of the two subjects) for the graduating high school students who took the test during the 2016/2017 year|
# |sat_participation_2018|*float*|sat_2018clean, sat_merged| The participation rate by state of graduating high school students who took the SAT during the 2017/2018 year (in decimal form, ex: .40 means 40%)|
# |sat_total_2018|*integer*|sat_2018clean, sat_merged| The total score (sum of the two subjects) for the graduating high school students who took the test during the 2017/2018 year|
# |sat_participation_2019|*float*|sat_2019clean, sat_merged| The participation rate by state of graduating high school students who took the SAT during the 2018/2019 year (in decimal form, ex: .40 means 40%)|
# |sat_total_2019|*integer*|sat_2019clean, sat_merged| The total score (sum of the two subjects) for the graduating high school students who took the test during the 2018/2019 year|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.

# %%
act_merged.describe()  #Using describe so I can visualize multiple stats at the same time for each feature
# Out:
#        act_participation_2017  act_composite_2017  act_participation_2018  \
# count               50.000000           50.000000               50.000000
# mean                 0.659200           21.466000                0.623200
# std                  0.321107            2.004241                0.341141
# min                  0.080000           17.800000                0.070000
# 25%                  0.310000           19.800000                0.277500
# 50%                  0.710000           21.400000                0.660000
# 75%                  1.000000           23.400000                1.000000
# max                  1.000000           25.500000                1.000000
#
#        act_composite_2018  act_participation_2019  act_composite_2019
# count           50.000000               50.000000           50.000000
# mean            21.454000                0.592000           21.424000
# std              2.111312                0.346534            2.197267
# ...

# %%
sat_merged.describe()
# Out:
#        sat_participation_2017  sat_total_2017  sat_participation_2018  \
# count               51.000000       51.000000               51.000000
# mean                 0.398039     1126.098039                0.457451
# std                  0.352766       92.494812                0.373143
# min                  0.020000      950.000000                0.020000
# 25%                  0.040000     1055.500000                0.045000
# 50%                  0.380000     1107.000000                0.520000
# 75%                  0.660000     1212.000000                0.775000
# max                  1.000000     1295.000000                1.000000
#
#        sat_total_2018  sat_participation_2019  sat_total_2019
# count       51.000000               51.000000       51.000000
# mean      1120.019608                0.490588     1113.078431
# std         94.155083                0.387476       97.197910
# min        977.000000                0.020000      943.000000
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
act_merged.columns
# Out:
# Index(['state', 'act_participation_2017', 'act_composite_2017',
#        'act_participation_2018', 'act_composite_2018',
#        'act_participation_2019', 'act_composite_2019'],
#       dtype='object')

# %%
sd_act = {column:manual_stdev(list(act_merged[column])) for column in list(act_merged.columns)
      if (act_merged[column].dtypes == 'float') | (act_merged[column].dtypes == 'int')}
# I had the skeleton but kept getting 'numpy.nparray' errors. Discussed this with Akira who helped and reminded me of the | operator.

# %%
sd_act
# Out:
# {'act_participation_2017': 0.3178794740149165,
#  'act_composite_2017': 1.9840977798485642,
#  'act_participation_2018': 0.33771254048376703,
#  'act_composite_2018': 2.090091864009809,
#  'act_participation_2019': 0.3430510166141473,
#  'act_composite_2019': 2.175183670405789}

# %%
sd_sat = {column:manual_stdev(list(sat_merged[column])) for column in list(sat_merged.columns) 
          if (sat_merged[column].dtypes == 'float') | (sat_merged[column].dtypes == 'int')}

# %%
sd_sat
# Out:
# {'sat_participation_2017': 0.3492907076664507,
#  'sat_total_2017': 91.58351056778743,
#  'sat_participation_2018': 0.3694661922353942,
#  'sat_total_2018': 93.22742384464433,
#  'sat_participation_2019': 0.3836584048685726,
#  'sat_total_2019': 96.24027185617864}

# %% [markdown]
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
act_2017clean.sort_values(by='act_participation_2017').head(3)  #Looking at the top and bottom of each dataset. I didn't use the merged datasets here because I had to sort by each specific column, so it wouldn't 
#                                                                     have made things quicker/simpler.
# Out:
#             state  act_participation_2017  act_composite_2017
# 20          Maine                    0.08                24.3
# 30  New Hampshire                    0.18                25.5
# 8        Delaware                    0.18                24.1

# %%
act_2017clean.sort_values(by='act_participation_2017', ascending=False).head(3)
# Out:
#         state  act_participation_2017  act_composite_2017
# 1     Alabama                     1.0                19.2
# 18   Kentucky                     1.0                20.0
# 50  Wisconsin                     1.0                20.5

# %% [markdown]
# Wow, there's quite a difference there. Let's keep going.

# %%
act_2018clean.sort_values(by='act_participation_2018').head(3)
# Out:
#             state  act_participation_2018  act_composite_2018
# 20          Maine                    0.07                24.0
# 40   Rhode Island                    0.15                24.2
# 30  New Hampshire                    0.16                25.1

# %%
act_2018clean.sort_values(by='act_participation_2018', ascending=False).head(3)
# Out:
#         state  act_participation_2018  act_composite_2018
# 0     Alabama                     1.0                19.1
# 17   Kentucky                     1.0                20.2
# 50  Wisconsin                     1.0                20.5

# %%
act_2019clean.sort_values(by='act_participation_2019').head(3)
# Out:
#            state  act_participation_2019  act_composite_2019
# 19         Maine                    0.06                24.3
# 39  Rhode Island                    0.12                24.7
# 7       Delaware                    0.13                24.1

# %%
act_2019clean.sort_values(by='act_participation_2019', ascending=False).head(3)
# Out:
#         state  act_participation_2019  act_composite_2019
# 0     Alabama                     1.0                18.9
# 17   Kentucky                     1.0                19.8
# 49  Wisconsin                     1.0                20.3

# %% [markdown]
# Let's see if that continues for SAT scores.

# %%
sat_2017clean.sort_values(by='sat_participation_2017').head(3)
# Out:
#            state  sat_participation_2017  sat_total_2017
# 34  North Dakota                    0.02            1256
# 24   Mississippi                    0.02            1242
# 15          Iowa                    0.02            1275

# %%
sat_2017clean.sort_values(by='sat_participation_2017', ascending=False).head(3)
# Out:
#                    state  sat_participation_2017  sat_total_2017
# 8   District of Columbia                     1.0             950
# 22              Michigan                     1.0            1005
# 6            Connecticut                     1.0            1041

# %%
sat_2018clean.sort_values(by='sat_participation_2018').head(3)
# Out:
#            state  sat_participation_2018  sat_total_2018
# 34  North Dakota                    0.02            1283
# 50       Wyoming                    0.03            1257
# 41  South Dakota                    0.03            1240

# %%
sat_2018clean.sort_values(by='sat_participation_2018', ascending=False).head(3)
# Out:
#          state  sat_participation_2018  sat_total_2018
# 5     Colorado                     1.0            1025
# 6  Connecticut                     1.0            1053
# 7     Delaware                     1.0             998

# %%
sat_2019clean.sort_values(by='sat_participation_2019').head(3)
# Out:
#            state  sat_participation_2019  sat_total_2019
# 34  North Dakota                    0.02            1263
# 52       Wyoming                    0.03            1238
# 42  South Dakota                    0.03            1268

# %%
sat_2019clean.sort_values(by='sat_participation_2019', ascending=False).head(3)
# Out:
#            state  sat_participation_2019  sat_total_2019
# 40  Rhode Island                     1.0             995
# 13      Illinois                     1.0            1013
# 22      Michigan                     1.0            1003

# %% [markdown]
# Across the board, it looks like the states that have the highest participation rates have lower test scores than those that have low participation rates.

# %%
act_merged[act_merged['act_composite_2017'] < 19.0]  # Looking at specific scores
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 23     Mississippi                     1.0                18.6
# 27          Nevada                     1.0                17.8
# 39  South Carolina                     1.0                18.7
#
#     act_participation_2018  act_composite_2018  act_participation_2019  \
# 23                     1.0                18.6                    1.00
# 27                     1.0                17.7                    1.00
# 39                     1.0                18.3                    0.78
#
#     act_composite_2019
# 23                18.4
# 27                17.9
# 39                18.8

# %%
act_merged[act_merged['act_composite_2018'] < 19.0]
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 10          Hawaii                     0.9                19.0
# 23     Mississippi                     1.0                18.6
# 27          Nevada                     1.0                17.8
# 39  South Carolina                     1.0                18.7
#
#     act_participation_2018  act_composite_2018  act_participation_2019  \
# 10                    0.89                18.9                    0.80
# 23                    1.00                18.6                    1.00
# 27                    1.00                17.7                    1.00
# 39                    1.00                18.3                    0.78
#
#     act_composite_2019
# 10                19.0
# 23                18.4
# 27                17.9
# 39                18.8

# %%
act_merged[act_merged['act_composite_2019'] < 19.0]
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                     1.0                19.2
# 17       Louisiana                     1.0                19.5
# 23     Mississippi                     1.0                18.6
# 27          Nevada                     1.0                17.8
# 35        Oklahoma                     1.0                19.4
# 39  South Carolina                     1.0                18.7
#
#     act_participation_2018  act_composite_2018  act_participation_2019  \
# 0                      1.0                19.1                    1.00
# 17                     1.0                19.2                    1.00
# 23                     1.0                18.6                    1.00
# 27                     1.0                17.7                    1.00
# 35                     1.0                19.3                    1.00
# 39                     1.0                18.3                    0.78
#
# ...

# %%
sat_merged[sat_merged['sat_total_2017'] < 1000]  #Again looking at specific scores
# Out:
#                   state  sat_participation_2017  sat_total_2017  \
# 7              Delaware                     1.0             996
# 8  District of Columbia                     1.0             950
#
#    sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 7                    1.00             998                    1.00
# 8                    0.92             977                    0.94
#
#    sat_total_2019
# 7             985
# 8             975

# %%
sat_merged[sat_merged['sat_total_2018'] < 1000]
# Out:
#                    state  sat_participation_2017  sat_total_2017  \
# 7               Delaware                    1.00             996
# 8   District of Columbia                    1.00             950
# 48         West Virginia                    0.14            1086
#
#     sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 7                     1.00             998                    1.00
# 8                     0.92             977                    0.94
# 48                    0.28             999                    0.99
#
#     sat_total_2019
# 7              985
# 8              975
# 48             943

# %%
sat_merged[sat_merged['sat_total_2019'] < 1000]
# Out:
#                    state  sat_participation_2017  sat_total_2017  \
# 7               Delaware                    1.00             996
# 8   District of Columbia                    1.00             950
# 9                Florida                    0.83            1017
# 12                 Idaho                    0.93            1005
# 36              Oklahoma                    0.07            1047
# 39          Rhode Island                    0.71            1062
# 48         West Virginia                    0.14            1086
#
#     sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 7                     1.00             998                    1.00
# 8                     0.92             977                    0.94
# 9                     0.56            1099                    1.00
# 12                    1.00            1001                    1.00
# 36                    0.08            1062                    0.22
# ...

# %%
act_merged.corr()
# Out:
#                         act_participation_2017  act_composite_2017  \
# act_participation_2017                1.000000           -0.854834
# act_composite_2017                   -0.854834            1.000000
# act_participation_2018                0.917604           -0.807682
# act_composite_2018                   -0.775676            0.940845
# act_participation_2019                0.903279           -0.796143
# act_composite_2019                   -0.776171            0.934019
#
#                         act_participation_2018  act_composite_2018  \
# act_participation_2017                0.917604           -0.775676
# act_composite_2017                   -0.807682            0.940845
# act_participation_2018                1.000000           -0.861362
# act_composite_2018                   -0.861362            1.000000
# act_participation_2019                0.989150           -0.851466
# act_composite_2019                   -0.860833            0.991679
#
# ...

# %%
sat_merged.corr()
# Out:
#                         sat_participation_2017  sat_total_2017  \
# sat_participation_2017                1.000000       -0.867540
# sat_total_2017                       -0.867540        1.000000
# sat_participation_2018                0.874763       -0.806796
# sat_total_2018                       -0.684556        0.852727
# sat_participation_2019                0.844118       -0.836916
# sat_total_2019                       -0.688327        0.900690
#
#                         sat_participation_2018  sat_total_2018  \
# sat_participation_2017                0.874763       -0.684556
# sat_total_2017                       -0.806796        0.852727
# sat_participation_2018                1.000000       -0.785926
# sat_total_2018                       -0.785926        1.000000
# sat_participation_2019                0.952967       -0.822584
# sat_total_2019                       -0.774900        0.905423
#
#                         sat_participation_2019  sat_total_2019
# ...

# %% [markdown]
# All of these features are pretty well correlated given they are very similar and aren't very many of them.

# %%
act_merged[act_merged['act_participation_2017'] > .99]  #Looking specifically at participation rates of 100% Doing each year within the merged file helps me see changes from 100% to others.
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                     1.0                19.2
# 3         Arkansas                     1.0                19.4
# 5         Colorado                     1.0                20.8
# 16        Kentucky                     1.0                20.0
# 17       Louisiana                     1.0                19.5
# 22       Minnesota                     1.0                21.5
# 23     Mississippi                     1.0                18.6
# 24        Missouri                     1.0                20.4
# 25         Montana                     1.0                20.3
# 27          Nevada                     1.0                17.8
# 32  North Carolina                     1.0                19.1
# 35        Oklahoma                     1.0                19.4
# 39  South Carolina                     1.0                18.7
# 41       Tennessee                     1.0                19.8
# ...

# %%
act_merged[act_merged['act_participation_2018'] > .99]
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                    1.00                19.2
# 3         Arkansas                    1.00                19.4
# 16        Kentucky                    1.00                20.0
# 17       Louisiana                    1.00                19.5
# 23     Mississippi                    1.00                18.6
# 24        Missouri                    1.00                20.4
# 25         Montana                    1.00                20.3
# 26        Nebraska                    0.84                21.4
# 27          Nevada                    1.00                17.8
# 32  North Carolina                    1.00                19.1
# 34            Ohio                    0.75                22.0
# 35        Oklahoma                    1.00                19.4
# 39  South Carolina                    1.00                18.7
# 41       Tennessee                    1.00                19.8
# ...

# %%
act_merged[act_merged['act_participation_2019'] > .99]
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                    1.00                19.2
# 3         Arkansas                    1.00                19.4
# 16        Kentucky                    1.00                20.0
# 17       Louisiana                    1.00                19.5
# 23     Mississippi                    1.00                18.6
# 25         Montana                    1.00                20.3
# 26        Nebraska                    0.84                21.4
# 27          Nevada                    1.00                17.8
# 32  North Carolina                    1.00                19.1
# 34            Ohio                    0.75                22.0
# 35        Oklahoma                    1.00                19.4
# 41       Tennessee                    1.00                19.8
# 43            Utah                    1.00                20.3
# 48       Wisconsin                    1.00                20.5
# ...

# %%
sat_merged[sat_merged['sat_participation_2017'] > .99]
# Out:
#                    state  sat_participation_2017  sat_total_2017  \
# 6            Connecticut                     1.0            1041
# 7               Delaware                     1.0             996
# 8   District of Columbia                     1.0             950
# 22              Michigan                     1.0            1005
#
#     sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 6                     1.00            1053                    1.00
# 7                     1.00             998                    1.00
# 8                     0.92             977                    0.94
# 22                    1.00            1011                    1.00
#
#     sat_total_2019
# 6             1046
# 7              985
# 8              975
# 22            1003

# %%
sat_merged[sat_merged['sat_participation_2018'] > .99]
# Out:
#           state  sat_participation_2017  sat_total_2017  \
# 5      Colorado                    0.11            1201
# 6   Connecticut                    1.00            1041
# 7      Delaware                    1.00             996
# 12        Idaho                    0.93            1005
# 22     Michigan                    1.00            1005
#
#     sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 5                      1.0            1025                     1.0
# 6                      1.0            1053                     1.0
# 7                      1.0             998                     1.0
# 12                     1.0            1001                     1.0
# 22                     1.0            1011                     1.0
#
#     sat_total_2019
# 5             1024
# 6             1046
# 7              985
# 12             993
# 22            1003

# %%
sat_merged[sat_merged['sat_participation_2019'] > .99]
# Out:
#            state  sat_participation_2017  sat_total_2017  \
# 5       Colorado                    0.11            1201
# 6    Connecticut                    1.00            1041
# 7       Delaware                    1.00             996
# 9        Florida                    0.83            1017
# 12         Idaho                    0.93            1005
# 13      Illinois                    0.09            1115
# 22      Michigan                    1.00            1005
# 39  Rhode Island                    0.71            1062
#
#     sat_participation_2018  sat_total_2018  sat_participation_2019  \
# 5                     1.00            1025                     1.0
# 6                     1.00            1053                     1.0
# 7                     1.00             998                     1.0
# 9                     0.56            1099                     1.0
# 12                    1.00            1001                     1.0
# ...

# %% [markdown]
# The states on the above lists coincide similarly with the list of states that still require one of the tests for graduation. <a href="https://prepmaven.com/blog/test-prep/states-require-sat-act/" target="_blank">Source</a>

# %%
act_merged[act_merged['state'] == 'Colorado']  #Colorado's stark changes stood out to me, looking at just their data
# Out:
#       state  act_participation_2017  act_composite_2017  \
# 5  Colorado                     1.0                20.8
#
#    act_participation_2018  act_composite_2018  act_participation_2019  \
# 5                     0.3                23.9                    0.27
#
#    act_composite_2019
# 5                23.8

# %%
sat_merged[sat_merged['state'] == 'Colorado']
# Out:
#       state  sat_participation_2017  sat_total_2017  sat_participation_2018  \
# 5  Colorado                    0.11            1201                     1.0
#
#    sat_total_2018  sat_participation_2019  sat_total_2019
# 5            1025                     1.0            1024

# %% [markdown]
# From what I can see above, the participation rates are negatively correlated with the respective year test scores. That trend continues from 2017 through 2019. It is also interesting to see that on a few occasions, the same states persist through each year as having the highest or lowest test scores or participation rates. However, there are a few states who have one-off appearances in the extremes.
#
# One state that stands out to me is Colorado. Between the years of 2017 to 2018, their participation rates and scores between the SAT and ACT invert: their participation rate for the ACT goes from 100% in 2017 to 30% and 27% the two years after. Meanwhile, the composite score average goes from 20.8 to 23.9 and 23.8 for the three years respectively. When looking at the SAT data, we can see that the participation rate went from 11% in 2017 to 100% for the following two years. Meanwhile, the total score average went from 1201 down to 1025 and 1024. This inverted change is very interesting.
#
#
#
# This trend is interesting to see. Yet unfortunately, there is not much data to deepen this exploration at this point. (Insert breakdown of some barriers to success on standardized tests and why we should no longer require them). One issue stands out to me - that high pressure required standardized tests can cause increased test anxiety that lowers scores. I tried to find some data to look into this, but it does not seem to exist in the US specifically in regards to test anxiety. However, there is one study that was done in the UK (insert some info about that here). It would be my recommendation that we conduct a similar study here in the US. Further,

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Boxplot 1
sat2017part = sat_2017clean['sat_participation_2017']
sat2018part = sat_2018clean['sat_participation_2018']
sat2019part = sat_2019clean['sat_participation_2019']

fig1 = sns.boxplot(data=[sat2017part, sat2018part, sat2019part], ax=axs[0,0])
fig1.title.set_text('SAT Participation 2017 to 2019')
fig1.set(xlabel=None)
fig1.set_xticklabels([2017, 2018, 2019])

# Boxplot 2
sat2017total = sat_2017clean['sat_total_2017']
sat2018total = sat_2018clean['sat_total_2018']
sat2019total = sat_2019clean['sat_total_2019']

fig2 = sns.boxplot(data=[sat2017total, sat2018total, sat2019total], ax=axs[1,0])
fig2.title.set_text('SAT Scores 2017 to 2019')
fig2.set(xlabel=None)
fig2.set_xticklabels([2017, 2018, 2019])

# Boxplot3
act2017part = act_2017clean['act_participation_2017']
act2018part = act_2018clean['act_participation_2018']
act2019part = act_2019clean['act_participation_2019']

fig3 = sns.boxplot(data=[act2017part, act2018part, act2019part], ax=axs[0,1])
fig3.title.set_text('ACT Participation 2017 to 2019')
fig3.set(xlabel=None)
fig3.set_xticklabels([2017, 2018, 2019])

# Boxplot 4
act2017comp = act_2017clean['act_composite_2017']
act2018comp = act_2018clean['act_composite_2018']
act2019comp = act_2019clean['act_composite_2019']

fig4 = sns.boxplot(data=[act2017comp, act2018comp, act2019comp], ax=axs[1,1])
fig4.title.set_text('ACT Scores 2017 to 2019')
fig4.set(xlabel=None)
fig4.set_xticklabels([2017, 2018, 2019])


;

plt.savefig('images/boxplots.png')

# Help on xticks: https://stackoverflow.com/questions/56605113/how-to-set-x-axis-ticklabels-in-a-seaborn-plot

# %% [markdown]
# Interpretation:
# These boxplots us the mean, median, and range of our dataset. What stands out here to me is the participation rate of the ACT us consistently weighted near 100%. However, once we get into 2019, we can see the range spreading into the lower percentages. It is interesting, as well, to see that the participation rate of the SAT hangs out on the lower ends, with an intverse relationship to the ACT where its' range is steadily increasing towards the higher percentages. Scores tend to stay the same centering around the middle of the score ranges.

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

fig1 = sns.histplot(data=act_merged, x='act_composite_2017', ax=axs[0,0])
fig1.title.set_text('ACT Scores 2017')
fig1.set(xlabel=None)


fig2 = sns.histplot(data=act_merged, x='act_composite_2018', ax=axs[1,0])
fig2.title.set_text('ACT Scores 2018')
fig2.set(xlabel=None)


fig3 = sns.histplot(data=act_merged, x='act_composite_2019', ax=axs[2,0])
fig3.title.set_text('ACT Scores 2019')
fig3.set(xlabel=None)


fig4 = sns.histplot(data=sat_merged, x='sat_total_2017', ax=axs[0,1])
fig4.title.set_text('SAT Scores 2017')
fig4.set(xlabel=None)


fig5 = sns.histplot(data=sat_merged, x='sat_total_2018', ax=axs[1,1])
fig5.title.set_text('SAT Scores 2018')
fig5.set(xlabel=None)


fig6 = sns.histplot(data=sat_merged, x='sat_total_2019', ax=axs[2,1])
fig6.title.set_text('SAT Scores 2019')
fig6.set(xlabel=None)

;

plt.savefig('images/scores_histogram.png')

# Help on histograms: https://python-graph-gallery.com/25-histogram-with-several-variables-seaborn

# %% [markdown]
# Interpretation:
# As we saw with the boxplots above, we can see in these histograms that the spread for scores on both tests hover around the middle. Of the two, the SAT data is more widely distributed than the ACT. We can see that as well with the standard deviation we calculated earlier of 90-100 points from the mean. Whereas, the ACT standard deviation sits at about 1-2 points of variation from the mean.

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))



fig1 = sns.histplot(data=act_merged, x='act_participation_2017', ax=axs[0,0])
fig1.title.set_text('ACT Participation 2017')
fig1.set(xlabel=None)

fig2 = sns.histplot(data=act_merged, x='act_participation_2018', ax=axs[1,0])
fig2.title.set_text('ACT Participation 2018')
fig2.set(xlabel=None)

fig3 = sns.histplot(data=act_merged, x='act_participation_2019', ax=axs[2,0])
fig3.title.set_text('ACT Participation 2019')
fig3.set(xlabel=None)

fig4 = sns.histplot(data=sat_merged, x='sat_participation_2017', ax=axs[0,1])
fig4.title.set_text('SAT Participation 2017')
fig4.set(xlabel=None)

fig5 = sns.histplot(data=sat_merged, x='sat_participation_2018', ax=axs[1,1])
fig5.title.set_text('SAT Participation 2018')
fig5.set(xlabel=None)

fig6 = sns.histplot(data=sat_merged, x='sat_participation_2019', ax=axs[2,1])
fig6.title.set_text('SAT Participation 2019')
fig6.set(xlabel=None)

;

plt.savefig('images/participation_histogram.png')

# Help on labels: https://stackoverflow.com/questions/25239933/how-to-add-title-to-subplots-in-matplotlib
# Help on titles: https://www.tutorialspoint.com/how-to-remove-or-hide-x-axis-labels-from-a-seaborn-matplotlib-plot

# %% [markdown]
# Interpretation:
# With these histograms, we again see the visualization we expected from the boxplots. The ACT participation rate consistently sits near 100%, while the SAT participation rate is consistently lower.

# %%
plt.figure(figsize=(10, 5))


plot17 = plt.scatter(x=act2017part, y=act2017comp)
plot18 = plt.scatter(x=act2018part, y=act2018comp)
plot19 = plt.scatter(x=act2019part, y=act2019comp)

plt.title('ACT scores and participation rates by state')

plt.xlabel('Participation rate (e.g., 0.4 = 40%)')
plt.ylabel('Composite score average')

plt.legend([plot17, plot18, plot19], ['2017', '2018', '2019']);


plt.savefig('images/scatter_ACT.png')
# Help for putting scatter plots over each other: https://stackoverflow.com/questions/4270301/matplotlib-multiple-datasets-on-the-same-scatter-plot
# Help on legend: https://matplotlib.org/2.0.2/users/legend_guide.html

# %% [markdown]
# Interpretation below.

# %%
plt.figure(figsize=(10, 5))


plot17 = plt.scatter(x=sat2017part, y=sat2017total)
plot18 = plt.scatter(x=sat2018part, y=sat2018total)
plot19 = plt.scatter(x=sat2019part, y=sat2019total)

plt.title('SAT scores and participation rates by state')

plt.xlabel('Participation rate (e.g., 0.4 = 40%)')
plt.ylabel('Total score average')

plt.legend([plot17, plot18, plot19], ['2017', '2018', '2019']);

plt.savefig('images/scatter_SAT.png')

# %% [markdown]
# Interpretation:
# We can see above the visualization of the negative correlation between participation and test scores. The trend persists between both the ACT and the SAT with mild clustering around the extremes. The highest test scores are majority correlated with low participation rates, and the low test scores are majority correlated with high participation rates. The SAT, however, shows greater variation, whereas the ACT spread is more consistent with the inverse relationship trend.

# %%
act_merged[act_merged['state'] == 'Colorado']
# Out:
#       state  act_participation_2017  act_composite_2017  \
# 5  Colorado                     1.0                20.8
#
#    act_participation_2018  act_composite_2018  act_participation_2019  \
# 5                     0.3                23.9                    0.27
#
#    act_composite_2019
# 5                23.8

# %%
plt.figure(figsize=(10, 5))


plot17 = plt.scatter(x=act2017part, y=act2017comp)
plot18 = plt.scatter(x=act2018part, y=act2018comp)
plot19 = plt.scatter(x=act2019part, y=act2019comp)

plt.annotate('Colorado 2017', (1.0, 20.8))
plt.annotate('Colorado 2018 and 2019', (0.3, 23.8))

plt.title('ACT scores and participation rates by state')

plt.xlabel('Participation rate (e.g., 0.4 = 40%)')
plt.ylabel('Composite score average')

plt.legend([plot17, plot18, plot19], ['2017', '2018', '2019']);

plt.savefig('images/scatter_colorado_ACT.png')

# Help for putting scatter plots over each other: https://stackoverflow.com/questions/4270301/matplotlib-multiple-datasets-on-the-same-scatter-plot
# Help on legend: https://matplotlib.org/2.0.2/users/legend_guide.html
# Help on annotations: https://www.delftstack.com/howto/matplotlib/matplotlib-label-scatter-plot-points/

# %%
sat_merged[sat_merged['state'] == 'Colorado']
# Out:
#       state  sat_participation_2017  sat_total_2017  sat_participation_2018  \
# 5  Colorado                    0.11            1201                     1.0
#
#    sat_total_2018  sat_participation_2019  sat_total_2019
# 5            1025                     1.0            1024

# %%
plt.figure(figsize=(10, 5))


plot17 = plt.scatter(x=sat2017part, y=sat2017total)
plot18 = plt.scatter(x=sat2018part, y=sat2018total)
plot19 = plt.scatter(x=sat2019part, y=sat2019total)

plt.annotate('Colorado 2017', (0.11, 1201))
plt.annotate('Colorado 2018 and 2019', (1.0, 1025))

plt.title('SAT scores and participation rates by state')

plt.xlabel('Participation rate (e.g., 0.4 = 40%)')
plt.ylabel('Total score average')

plt.legend([plot17, plot18, plot19], ['2017', '2018', '2019']);

plt.savefig('images/scatter_colorado_SAT.png')

# %% [markdown]
# Interpretation:
# I wanted to single out Colorado on these graphs so we can visualize the relationship we discussed earlier. The two graphs above show where Colorado sits on these graphs. Let's look at the story behind this information.
#
# ---
#
#
# In 2017, Colorado decided to transition from using the ACT as their required graduation exam to the SAT. These changes were reflected during the 2017/2018 school year which coincides with the 2018 data findings above (<a href="https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf" target="_blank">Source</a>). As discussed above, the scores and participation rates inverted over the 2017 to 2018 years and persisted through 2019. This data further shows us that the requirement of the SAT or ACT to graduate can alter student outcomes. A theory as to why this happens is that when the tests are not a requirement, the students who want to opt out, do. The students who want to take them do. The reasons students may want to opt out could be because the tests are inaccessible financially, they do not need to take them for college admissions, or because, simply, they do not want to take them. The lack of requirement gives students the freedom to choose what course they would like to take.
#
# While lower participation rates do not by any means guarantee there will be no test anxiety or solve major mental health issues, it may offer reprieve to those who do not feel ready to take them or who do not want to take them as they feel they do not need them. I would like to explore this relationship between mental health and taking or not taking standardized tests. I believe it would aid in our work to ensure safe and accessible education to high school students.
#
# To emphasize the importance of mental health research, a look at more outside research is necessary. The Healthy People 2020 objectives, which are released every 10 years and analyze factors and objectives related to physical and mental health of Americans, include reducing the number of adolescents affected by suicide, reducing the amount of mental health episodes experienced by adolescents, and increasing the access to mental health services for children and adolescents with mental health issues (<a href="https://communities.socrata.com/Health/Healthy-People-2020-Mental-Health-and-Mental-Disor/6fk8-5qyt" target="_blank">Source</a>). Let's look at their data.

# %% [markdown]
# ![MDE adolescents.png](attachment:3e061592-1339-4fa6-88c4-c82c0e1bac17.png)
# <a href="https://www.healthypeople.gov/2020/data-search/Search-the-Data?nid=4813" target ="_blank">Source</a>

# %% [markdown]
# ![children receiving treatment.png](attachment:4c846a3e-cd58-444b-a0d4-c9228b6de8b5.png)
# <a href="https://www.healthypeople.gov/2020/data-search/Search-the-Data?nid=4816" target="_blank">Source</a>

# %% [markdown]
# ![suicide attempts.png](attachment:763d74d4-2767-4219-a4b5-fb393b232778.png)
# <a href="https://www.healthypeople.gov/2020/data-search/Search-the-Data?nid=4810" target="_blank">Source</a>

# %% [markdown]
# Each of the above graphs shows one HealthyPeople2020 objective and their progress. As we can see, while we are close to providing sufficient treatment access for children, none of the objectives are being met. In fact, adolescents having major depressive episodes are increasing. We can also look at data that shows mental health concerns persisting into college and adulthood:

# %% [markdown]
# ![college student mental health.png](attachment:ea658033-962e-4833-98fc-fb5b071f3537.png)
# <a href="https://www.statista.com/statistics/827374/clinician-chosen-top-mental-health-concerns-for-college-students/" target="_blank">Source</a>

# %% [markdown]
# ![adult mental health.png](attachment:27f133ec-ae4d-4149-9d9b-f5bb5c4249e5.png)
# <a href="https://www.statista.com/statistics/252311/mental-illness-in-the-past-year-among-us-adults-by-age-and-gender/" target="_blank">Source</a>

# %% [markdown]
# From the visualizations above, we can see that significant mental health concerns exist for college students, including stress and anxiety. Further, a considerable amount of adults from every age group have experienced mental illness in 2020 alone. Therefore, considering we know that high school students begin to experience significant self-esteem concerns and academic-related anxiety in middle school and that it persists into high school (<a href="https://www.sciencedirect.com/science/article/abs/pii/S0165032717303683" target="_blank">Source</a>), it could be beneficial to explore the relationship between mental health and standardized testing and academia.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Initially, I sought out to explore the relationship between standardized testing participation rates and their scores. I had already addressed the background of the tests, understanding that test anxiety and mental health alone can have an impact on performance. What I found in the data is that when there is a requirement or a push for 100% participation, student performance suffers. Colorado's findings show us that when the pressure is off, students may actually do better.
#
# Recently, there has been a very popular push to no longer require the SAT and ACT scores to be admitted to college, with 76% of universities opting out for the 2020/2021 school year (<a href="https://www.fairtest.org/record-1775-schools-are-testoptional-fall-2022" target="_blank">Source</a>). This means students no longer face that barrier if they want to apply to college. However, some students are still facing this barrier when trying to graduate high school. The required standardized testing to graduate can cause pressure, anxiety, and stress in high school students that could impact student performance. We saw above that college students' main concern when seeing a mental health professional is first anxiety, then depression and stress after. Mental health is a concern of young people and is important to address.
#
# My conclusion from the data I analyzed is that there is some relationship between lower participation rates and higher scores, showing potential that the lack of requirement helps students who want to take the tests to feel more comfortable on exam day. My recommendation is that we apply for grant funding to research the intersection of these two issues: required standardized testing and mental health of young people. A recent, robust study for this potential relationship does not yet exist in the US, and I hope today's presentation gives you the foundation to see why it would be important for us to accomplish.
#
#
# ---
#
# ## Review of My Work and Next Steps
#
# I would like to step out of the scenario I created for this project. I am very proud of the work I created here. I have never done anything like this before. While I was frustrated in finding a lack of data, I feel I was still able to complete a considerable amount and a solid exploratory analysis of the data I did have. If I were to complete this project again, I would go more indepth with data about students who do or do not attend college; students who took the ACT/SAT and how they did in college and if they completed it; and mental health of college students in regards to test anxiety. While it is not a new concept (that test anxiety can reduce test scores), I really wanted to focus on mental health for my topic. I feel that focus hindered me from creating a more robust study with several features and more complicated analyses. If I had more time and realized sooner that I lacked the necessary data to do that, I may have chosen a different topic. However, again, for being the first time I have done this, I am excited to see how my skills have grown. I will also be learning how to do visualization functions.
